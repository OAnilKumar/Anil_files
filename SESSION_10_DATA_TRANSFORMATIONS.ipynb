# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA TRANSFORMANTIONS
#
# - GENERALLY DARA HAS 3 TYPES OF TRANSFORMATIONS
#
#      - NORMAL DISTRIBUTION
#
#      - POSITIVE SKEWED
#
#      - NEGATIVE SKEWED
#
# - ALL THE MATH CONCEPTS DEVELOPED BY ASSUMPTIONS AS DATA FOLLOWS NORMAL DISTRIBUTION
#
# - DATA SKEW HAPPENS BECAUSE OF MANY REASONS , IN THAT ONE REASON IS OUTLIERS
#
# - ONCE WE APPLY THE OUTLIER ANALYSIS THEN WE CAN APPLY TRANSFORMATIONS METHODS , IF THE DATA DOES NOT FOLLW NORMALITY
#
# - WE HAVE SOME TRANSFORMATION METHODS MENTIONED BELOW
#
#     - LOG TRANSFORMATION
#
#     - EXPONENTIONAL TRANSFORMATION
#
#     - RECIPROCAL TRANSFORMATION
#
#     - SQUARE ROOT TRANSFORMATION
#
#     - POWER TRANSFORMATION

# %%
visa_df=pd.read_csv('Visadataset - Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # step -2

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.54315682, 0.23182354, 0.69823467, ..., 2.53172659, 0.02670259,
#        0.29644671])

# %% [markdown]
# # step - 3

# %% [markdown]
# # plot the data

# %%
plt.hist(exp_data,bins=20,label='Exponential')
plt.show()

# %%
norm_data=np.random.normal(size=10000)
plt.hist(norm_data,bins=20,label='Exponential')
norm_data
# Out:
# array([ 1.07767459, -1.77979324, -0.521441  , ...,  0.22841476,
#         0.97760513,  0.75556775])

# %% [markdown]
# # GOAL
#
# # CONVERT EXP_DATA TO NORMAL DISTRIBUTION
#
# BINS=INTERVALS

# %% [markdown]
# # STEP-4
#
# - **LOG TRANSFORMATION**
#
# - LOG TRANSFORMATION MEANS PERFORMAING LOGARITHM OPERATIONS ON ORIGINAL DATA
#
# - IT IS AN APPROACH TO CONVERT INTO NORMAL DISTRIBUTION
#
# - LOG MEANS NATURAL LOGARITHM BASE = e

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([-0.6103572 , -1.4617788 , -0.35920002, ...,  0.92890152,
#        -3.6229949 , -1.2158878 ])

# %%
plt.hist(log_data,bins=20,label='Logarithm')
plt.show()

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,2,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
plt.show()

# %% [markdown]
# # RECIPROCAL TRANSFORMATION

# %% [markdown]
# - RECIPROCAL WILL FAILS WHEN VALUES HAS VERY LESS
#
# - FOR EXAMPLE X=0 THE 1/0 FAILS

# %%
X=2
1/X
# Out:
# 0.5

# %%
reciprocal_data=1/exp_data
reciprocal_data
# Out:
# array([0.89321237, 0.67567832, 2.36404188, ..., 0.42143485, 8.61696075,
#        2.26822741])

# %%
reciprocal_data=np.reciprocal(exp_data)
plt.hist(reciprocal_data,bins=20,label='Reciprocal')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(3,3,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
plt.subplot(3,3,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
plt.subplot(3,3,3).hist(reciprocal_data,bins=20,label='Reciprocal')
plt.legend()
plt.show()

# %% [markdown]
# # SQUARE ROOT transformation

# %%
square_root_data=np.sqrt(exp_data)
plt.hist(square_root_data,bins=20,label='Square root Data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,9))
plt.subplot(3,3,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
plt.subplot(3,3,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
plt.subplot(3,3,3).hist(square_root_data,bins=20,label='Square root Data')
plt.legend()
plt.show()

# %% [markdown]
# # POWER TRANSFORMATION

# %% [markdown]
# - BOX COX
#
# - YE-JHONSON
#
# - IT IS UNDER SKLEARN PREPROCESSING

# %% [markdown]
# <img id="dimg_12" src="data:image/png;base64,..." class="YQ4gaf" height="118" style="object-position:45% 63%" width="428" alt="Power Transformations In Machine Learning" data-csiid="24" data-atf="1">

# %%
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer(method='yeo-johnson')
exp_data1=exp_data.reshape(-1,1)
data_trans=power.fit_transform(exp_data1)
plt.hist(data_trans)
# Out:
# (array([1148., 1189., 1351., 1327., 1400., 1345., 1119.,  769.,  313.,
#           39.]),
#  array([-1.75730874e+00, -1.31838873e+00, -8.79468719e-01, -4.40548711e-01,
#         -1.62870196e-03,  4.37291307e-01,  8.76211315e-01,  1.31513132e+00,
#          1.75405133e+00,  2.19297134e+00,  2.63189135e+00]),
#  <BarContainer object of 10 artists>)

# %%
exp_data
# Out:
# array([0.54315682, 0.23182354, 0.69823467, ..., 2.53172659, 0.02670259,
#        0.29644671])

# %%
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer(method='box-cox')
exp_data1=exp_data.reshape(-1,1)
box_cox_data_trans=power.fit_transform(exp_data1)
plt.hist(box_cox_data_trans)
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1).hist(data_trans,bins=20,label='Yeo-Johnson')
plt.legend()
plt.subplot(1,2,2).hist(box_cox_data_trans,bins=20,label='Box-Cox')
plt.legend()
plt.show()
