# %% [markdown]
# **IMPORT THE PACKAGES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv("Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # STANDARAIZATION
#
# - STANDARDIZATION IS A TECHNIQUE : SCALE ALL THE DATA UNDER ONE SCALE
#
# - DIFFERENT COLUMNS HAS DIFFERENT VALUES ALSO DIFFERENT UNITS
#
# - SOME COLUMN VALUE HAS BIGGER VALUES, SOME COLUMNS HAS VERY LESS VALUES
#
# - SO IT IS IMPORTTANT TO KEEP ALL THE VALUES UNDER ONE SCALE
#
# - WE HAVE TWO METHODS ARE THERE
#
#     - STANDARDIZATION
#
#     - NORMALIZATION
#
# - STANDARDIZATION
#
#     - Z-SCORE
#
#     - Z SCORE VARIES VALUES FROM -3 TO 3
#
#     - <img class="XqHOTb IGEbUc" alt="Z = \frac{x - \mu}{\sigma}" src="https://www.gstatic.com/education/formulas2/553212783/en/z_score.svg" role="img" data-csiid="21" data-atf="0">

# %% [markdown]
# - NORMALIZATION
#
#    - min max scalar
#
#   - values ranges from 0 to 1

# %% [markdown]
# **TASK**
#
# - STEP-1 :TAKE PREVALING WAGE COLUMN
#
# - STEP-2 : CALCULATE THE MEAN VALUE OF PREWALING WAGE
#
# - STEP-3 : CALCULATE THE STANDARD DEVIATION OF PREVAILING WAGE
#
# - STEP-4 : CALCULATE THE NUMERATOR : STEP-1-STEP-2
#
# - STEP-5 : DIVIDE THE STEP4/STEP3

# %%
col=visa_df['prevailing_wage']

# %%
mean=visa_df['prevailing_wage'].mean()
mean
# Out:
# 74455.81459209183

# %%
std=visa_df['prevailing_wage'].std()
std
# Out:
# 52815.94232687357

# %%
numerator=visa_df['prevailing_wage']-visa_df['prevailing_wage'].mean()
numerator
# Out:
# 0        -73863.611692
# 1          8969.835408
# 2         48541.045408
# 3          8978.215408
# 4         75451.575408
#              ...
# 25475      2636.755408
# 25476    204718.975408
# 25477     71843.035408
# 25478     11698.955408
# 25479     -3578.904592
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
numerator/std
# Out:
# 0       -1.398510
# 1        0.169832
# 2        0.919060
# 3        0.169991
# 4        1.428576
#            ...
# 25475    0.049923
# 25476    3.876083
# 25477    1.360253
# 25478    0.221504
# 25479   -0.067762
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
mean=visa_df['prevailing_wage'].mean()
std=visa_df['prevailing_wage'].std()
numerator=visa_df['prevailing_wage']-visa_df['prevailing_wage'].mean()
numerator/std
# Out:
# 0       -1.398510
# 1        0.169832
# 2        0.919060
# 3        0.169991
# 4        1.428576
#            ...
# 25475    0.049923
# 25476    3.876083
# 25477    1.360253
# 25478    0.221504
# 25479   -0.067762
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
col=visa_df['prevailing_wage']
mean=visa_df['prevailing_wage'].mean()
std=visa_df['prevailing_wage'].std()
numerator=visa_df['prevailing_wage']-visa_df['prevailing_wage'].mean()
visa_df['prevailing_wage_z']=numerator/std
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **TASK-2**
#
# - COMPARE THETWO COLUMNS
#
# - GET THE MAXIMUM VALUE AND MINIMUM VALUE OF THE INDEXES
#
# - THE BOTH INDEXES SHOULD MATCH

# %% [markdown]
# **IDXMAX-IDXMIN**

# %%
maxx=visa_df['prevailing_wage'].idxmax(),visa_df['prevailing_wage_z'].idxmax()
minn=visa_df['prevailing_wage'].idxmin(),visa_df['prevailing_wage_z'].idxmin()

maxx,minn
# Out:
# ((21077, 21077), (20575, 20575))

# %%
max_val=visa_df['prevailing_wage'].max(),visa_df['prevailing_wage_z'].max()
min_val=visa_df['prevailing_wage'].min(),visa_df['prevailing_wage_z'].min()

max_val,min_val
# Out:
# ((319210.27, 4.634101837909902), (2.1367, -1.4096818992891214))

# %% [markdown]
# # STANDARD SCALAR
#
# - IT IS ALSO SAME AS Z-SCORE BUT BY USING PACKAGE
#
# - IT IS UNDER SKLEARN PACKAGE
#
# - IN THE SKLEARN WE HAVE PREPROCESSING
#
#
# - READ THE PACKAGE
#
# - SAVE THE PACKAGE
#
# - APPLY FIT TRANSFORM
#
# - COMPARE 3 COLUMNS
#
#     - ONE IS ORIGINAL COLUMN
#
#     - MANUALLY WE DID Z-SCORE
#
#     - COLUMN WITH PACKAGE

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
# Out:
#        prevailing_wage  prevailing_wage_z  prevailing_wage_ss
# 0             592.2029          -1.398510           -1.398537
# 1           83425.6500           0.169832            0.169835
# 2          122996.8600           0.919060            0.919079
# 3           83434.0300           0.169991            0.169994
# 4          149907.3900           1.428576            1.428604
# ...                ...                ...                 ...
# 25475       77092.5700           0.049923            0.049924
# 25476      279174.7900           3.876083            3.876159
# 25477      146298.8500           1.360253            1.360280
# 25478       86154.7700           0.221504            0.221509
# 25479       70876.9100          -0.067762           -0.067763
#
# [25480 rows x 3 columns]

# %% [markdown]
# # NORMALIZATION

# %%
visa_df=pd.read_csv("Visadataset - Visadataset.csv")
col=visa_df['prevailing_wage']
min=visa_df['prevailing_wage'].min()
max=visa_df['prevailing_wage'].max()
numerator=visa_df['prevailing_wage']-min
denominator=max-min
visa_df['prevailing_wage_n']=numerator/denominator
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **package_name=MinMaxScalar**

# %%
maxx=visa_df['prevailing_wage'].idxmax(),visa_df['prevailing_wage_n'].idxmax()
minn=visa_df['prevailing_wage'].idxmin(),visa_df['prevailing_wage_n'].idxmin()

maxx,minn
# Out:
# ((21077, 21077), (20575, 20575))

# %%
visa_df[['prevailing_wage','prevailing_wage_n']]
# Out:
#        prevailing_wage  prevailing_wage_n
# 0             592.2029           0.001849
# 1           83425.6500           0.261345
# 2          122996.8600           0.385312
# 3           83434.0300           0.261371
# 4          149907.3900           0.469616
# ...                ...                ...
# 25475       77092.5700           0.241505
# 25476      279174.7900           0.874579
# 25477      146298.8500           0.458311
# 25478       86154.7700           0.269895
# 25479       70876.9100           0.222033
#
# [25480 rows x 2 columns]
